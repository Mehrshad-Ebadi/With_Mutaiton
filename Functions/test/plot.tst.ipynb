# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
G = np.loadtxt('./boz.txt')

# %%
plt.plot(G)

# %%
G
# Out:
# array([1., 1., 2., 1., 1., 0., 1., 1., 1., 1., 1., 1., 2., 1., 1., 1., 2.,
#        0., 0., 1.])

# %%
for i in range (0, len(G)):
    G[i] = round(G[i])

# %%
sum(G)
# Out:
# 20.0
