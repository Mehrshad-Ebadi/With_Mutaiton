# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('./Outputs/st_1000,nn_1000,mu_0.100000,ref_env_=0.000000/numrun_0/num_mutation.txt',sep='\t',header=None)

# %%
df = pd.DataFrame(df)

# %%
plt.plot(df[0],df[1])
plt.plot(df[0],df[2])
