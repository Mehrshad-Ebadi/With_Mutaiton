# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
adress_variable_part = 'st_2000,nn_1000,mu_0.100000,ref_env_=0.000000'
address = './Outputs/' + adress_variable_part + '/numrun_0/Alive.txt'
df = pd.read_csv(address,sep='\t',header=None)

# %%
df = pd.DataFrame(df)

# %%
df_filtered = df[(df.index >= 500) & (df.index <= 1500)]

# %%
df_filtered
# Out:
#          0      1
# 500    500  0.693
# 501    501  0.760
# 502    502  0.751
# 503    503  0.722
# 504    504  0.749
# ...    ...    ...
# 1496  1496  0.640
# 1497  1497  0.698
# 1498  1498  0.659
# 1499  1499  0.649
# 1500  1500  0.659
#
# [1001 rows x 2 columns]

# %%
plt.plot(df_filtered[0],df_filtered[1])
plt.plot(df[0],df[1],alpha=0.6)
